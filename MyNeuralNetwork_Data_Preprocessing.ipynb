# %%
## Mounting google drive
from google.colab import drive
drive.mount('/content/drive')

# %%
## Importing necessary libraries
import pandas as pd
import numpy as np

# %%
## Loading data file
Data=pd.read_csv('/content/drive/MyDrive/ce889_dataCollection.csv')

# %%
Data.head()
# Out:
#    291.31958975807584  307.1  0.0  0.0.1
# 0           291.31959  307.1 -0.1   0.04
# 1           291.27959  307.2 -0.2   0.00
# 2           291.27959  307.4 -0.3   0.04
# 3           291.23959  307.7 -0.4   0.00
# 4           291.23959  308.1 -0.5   0.04

# %%
## Missing Value
Data.isnull().sum()

# %%
## Checking for duplicates
Data.duplicated()

# %%
## Data shape and info
print(f"Data shape = {Data.shape} \n")
print('~'*50 + '\n')
Data.info()
